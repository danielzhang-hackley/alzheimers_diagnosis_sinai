# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = pd.read_csv(r'../data/X.csv')
X.drop(['Unnamed: 0', 'seqLibID'], axis=1, inplace=True)

# %%
data = X.values
counts, bins = np.histogram(data[: , 1900])
plt.stairs(counts, bins)
